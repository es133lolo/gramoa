# %%
import os
import numpy as np
import pandas as pd
import pyedflib
from pyedflib import highlevel
from scipy.signal import resample
from sklearn.utils import shuffle
import json
import mne

# %%
SAMPLE_RATE = 128  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '128Hz'

# %%
root = 'CAUEEG/'
# participants file path
annotation_path = os.path.join(root, 'annotation.xlsx')
annotations = pd.read_excel(annotation_path)
annotations
# Out:
#       serial  age  dementia   ad  load  eoad  vd  sivd  ad_vd_mixed  mci  ...  \
# 0          1   78       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# 1          2   56       NaN  NaN   NaN   NaN NaN   NaN          NaN  NaN  ...
# 2          3   93       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# 3          4   78       1.0  1.0   1.0   NaN NaN   NaN          NaN  NaN  ...
# 4          5   75       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# ...      ...  ...       ...  ...   ...   ...  ..   ...          ...  ...  ...
# 1374    1384   57       1.0  1.0   NaN   1.0 NaN   NaN          NaN  NaN  ...
# 1375    1385   77       1.0  1.0   1.0   NaN NaN   NaN          NaN  NaN  ...
# 1376    1386   80       1.0  1.0   1.0   NaN NaN   NaN          NaN  NaN  ...
# 1377    1387   83       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# 1378    1388   73       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
#
#       ftd  bvftd  language_ftd  semantic_aphasia  non_fluent_aphasia  \
# 0     NaN    NaN           NaN               NaN                 NaN
# 1     NaN    NaN           NaN               NaN                 NaN
# 2     NaN    NaN           NaN               NaN                 NaN
# 3     NaN    NaN           NaN               NaN                 NaN
# 4     NaN    NaN           NaN               NaN                 NaN
# ...   ...    ...           ...               ...                 ...
# 1374  NaN    NaN           NaN               NaN                 NaN
# 1375  NaN    NaN           NaN               NaN                 NaN
# 1376  NaN    NaN           NaN               NaN                 NaN
# 1377  NaN    NaN           NaN               NaN                 NaN
# 1378  NaN    NaN           NaN               NaN                 NaN
#
#       parkinson_synd  parkinson_disease  parkinson_dementia  nph  tga
# 0                NaN                NaN                 NaN  NaN  NaN
# 1                NaN                NaN                 NaN  NaN  NaN
# 2                NaN                NaN                 NaN  NaN  NaN
# 3                NaN                NaN                 NaN  NaN  NaN
# 4                NaN                NaN                 NaN  NaN  NaN
# ...              ...                ...                 ...  ...  ...
# 1374             NaN                NaN                 NaN  NaN  NaN
# 1375             NaN                NaN                 NaN  NaN  NaN
# 1376             NaN                NaN                 NaN  NaN  NaN
# 1377             NaN                NaN                 NaN  NaN  NaN
# 1378             NaN                NaN                 NaN  NaN  NaN
#
# [1379 rows x 31 columns]

# %% [markdown]
# ## Labels

# %%
conditions = [
    annotations["dementia"] == 1,         # condition 1：Dementia: Alzheimer's Disease, Vascular Dementia, Parkinson's Dementia 
    annotations["mci"] == 1,        # condition 2：Mild Cognitive Impairment
    annotations["normal"] == 1      # condition 3：Normal control
]
choices = [1, 2, 0]        # corresponding labels, De=1, MCI=2, NC=0

# np.select, if no condition is met, default to 3
annotations["label"] = np.select(conditions, choices, default=3)
annotations
# Out:
#       serial  age  dementia   ad  load  eoad  vd  sivd  ad_vd_mixed  mci  ...  \
# 0          1   78       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# 1          2   56       NaN  NaN   NaN   NaN NaN   NaN          NaN  NaN  ...
# 2          3   93       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# 3          4   78       1.0  1.0   1.0   NaN NaN   NaN          NaN  NaN  ...
# 4          5   75       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# ...      ...  ...       ...  ...   ...   ...  ..   ...          ...  ...  ...
# 1374    1384   57       1.0  1.0   NaN   1.0 NaN   NaN          NaN  NaN  ...
# 1375    1385   77       1.0  1.0   1.0   NaN NaN   NaN          NaN  NaN  ...
# 1376    1386   80       1.0  1.0   1.0   NaN NaN   NaN          NaN  NaN  ...
# 1377    1387   83       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
# 1378    1388   73       NaN  NaN   NaN   NaN NaN   NaN          NaN  1.0  ...
#
#       bvftd  language_ftd  semantic_aphasia  non_fluent_aphasia  \
# 0       NaN           NaN               NaN                 NaN
# 1       NaN           NaN               NaN                 NaN
# 2       NaN           NaN               NaN                 NaN
# 3       NaN           NaN               NaN                 NaN
# 4       NaN           NaN               NaN                 NaN
# ...     ...           ...               ...                 ...
# 1374    NaN           NaN               NaN                 NaN
# 1375    NaN           NaN               NaN                 NaN
# 1376    NaN           NaN               NaN                 NaN
# 1377    NaN           NaN               NaN                 NaN
# 1378    NaN           NaN               NaN                 NaN
#
#       parkinson_synd  parkinson_disease  parkinson_dementia  nph  tga  label
# 0                NaN                NaN                 NaN  NaN  NaN      2
# 1                NaN                NaN                 NaN  NaN  NaN      0
# 2                NaN                NaN                 NaN  NaN  NaN      2
# 3                NaN                NaN                 NaN  NaN  NaN      1
# 4                NaN                NaN                 NaN  NaN  NaN      2
# ...              ...                ...                 ...  ...  ...    ...
# 1374             NaN                NaN                 NaN  NaN  NaN      1
# 1375             NaN                NaN                 NaN  NaN  NaN      1
# 1376             NaN                NaN                 NaN  NaN  NaN      1
# 1377             NaN                NaN                 NaN  NaN  NaN      2
# 1378             NaN                NaN                 NaN  NaN  NaN      2
#
# [1379 rows x 32 columns]

# %%
df_label = annotations[['label','serial']]
label_path = 'Processed/' + sub_folder_path + '/CAUEEG/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)
    
np.save(label_path + '/label.npy', df_label.values)

# %%
np.load(label_path + '/label.npy')
# Out:
# array([[   2,    1],
#        [   0,    2],
#        [   2,    3],
#        ...,
#        [   1, 1386],
#        [   2, 1387],
#        [   2, 1388]], dtype=int64)

# %% [markdown]
# ## Features

# %%
f = pyedflib.EdfReader("CAUEEG/signal/edf/00001.edf")
channels = f.getSignalLabels()
f.close()

# %%
channels
# Out:
# ['Fp1-AVG',
#  'F3-AVG',
#  'C3-AVG',
#  'P3-AVG',
#  'O1-AVG',
#  'Fp2-AVG',
#  'F4-AVG',
#  'C4-AVG',
#  'P4-AVG',
#  'O2-AVG',
#  'F7-AVG',
#  'T3-AVG',
#  'T5-AVG',
#  'F8-AVG',
#  'T4-AVG',
#  'T6-AVG',
#  'FZ-AVG',
#  'CZ-AVG',
#  'PZ-AVG',
#  'EKG',
#  'Photic']

# %%
# 'Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'T3', 'C3', 'Cz', 'C4', 'T4', 'T5', 'P3', 'Pz', 'P4', 'T6', 'O1', 'O2'
li_std_ch = ['Fp1-AVG', 'Fp2-AVG', 'F7-AVG', 'F3-AVG', 'FZ-AVG', 'F4-AVG', 'F8-AVG', 'T3-AVG', 'C3-AVG', 'CZ-AVG', 'C4-AVG', 'T4-AVG', 'T5-AVG', 'P3-AVG', 'PZ-AVG', 'P4-AVG', 'T6-AVG', 'O1-AVG', 'O2-AVG']

# %%
def generate_mask_from_events(json_path, total_samples, sample_rate=256, artifact_keywords=None):
    """
    Generate a boolean mask for valid EEG samples based on events.
    Marks valid recording periods and excludes artifacts + HV intervals.

    Parameters
    ----------
    json_path : str
        Path to the event JSON file.
    total_samples : int
        Total number of EEG samples.
    sample_rate : int
        Sampling rate in Hz (default: 256).
    artifact_keywords : list of str, optional
        Keywords to detect noisy artifacts (default: common EEG noise terms).

    Returns
    -------
    mask : np.ndarray of bool
        Boolean array indicating valid EEG data samples.
    """

    if artifact_keywords is None:
        artifact_keywords = [
            'artifact', 'blink', 'eye', 'noise', 'movement', 'move', 'cough',
            'muscle', 'chewing', 'swallow', 'talk', 'sleep', 'sweating', 'jerking', 'drowsy'
        ]

    with open(json_path, 'r') as f:
        events = json.load(f)

    mask = np.zeros(total_samples, dtype=bool)

    # Step 1: Mark valid recording periods
    is_recording = False
    segment_start = None
    for timestamp, label in events:
        label_lower = label.lower()
        if label_lower in ("start recording", "recording resumed"):
            segment_start = timestamp
            is_recording = True
        elif label_lower == "paused" and is_recording:
            segment_end = timestamp
            mask[segment_start:min(segment_end, total_samples)] = True
            is_recording = False
            segment_start = None

    # Step 2: Remove artifact regions (±1s)
    for timestamp, label in events:
        label_lower = label.lower()
        if any(key in label_lower for key in artifact_keywords):
            start = max(0, timestamp - int(1 * sample_rate))
            end = min(total_samples, timestamp + int(1 * sample_rate))
            mask[start:end] = False

    return mask

# %%
# resample the time series data from original_fs to target_fs
def resample_time_series(data, original_fs, target_fs):
    T, C = data.shape
    new_length = int(T * target_fs / original_fs)

    resampled_data = np.zeros((new_length, C))
    for i in range(C):
        resampled_data[:, i] = resample(data[:, i], new_length)

    return resampled_data

def band_pass_filter(
    eeg_data: np.ndarray,
    sfreq: float,
    ch_names: list,
    verbose=True
):
    """
    Clean EEG data using bandpass filtering, percentile-based bad channel detection,
    ICA + ICLabel artifact removal, resampling, re-referencing, epoching, and z-score normalization.

    Args:
        eeg_data (np.ndarray): EEG data, shape (T, C).
        sfreq (float): Original sampling frequency.
        ch_names (list): List of channel names.
        resample_sfreq (float): Target sampling frequency.
        verbose (bool): Verbose output.

    Returns:
        np.ndarray: Cleaned, normalized EEG data, shape (n_epochs, time_steps, channels).
    """
    # 1. Construct MNE Raw object
    info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=['eeg'] * len(ch_names))
    raw = mne.io.RawArray(eeg_data.T, info)

    # 2. Set Montage
    raw.set_montage(mne.channels.make_standard_montage('standard_1020'))
    if verbose:
        print("✔ Montage set: 'standard_1020'.")

    #  Bandpass Filter (0.5–45 Hz)
    raw.filter(l_freq=0.5, h_freq=45.0, verbose=False)
    if verbose:
        print("✔ Bandpass filter applied (0.5–45 Hz).")
        
    return raw.get_data().T
        

def eeg_data(std_edf_path, event_path, li_std_ch, target_freq=128):
    signals, signal_headers, _ = highlevel.read_edf(std_edf_path, ch_names=li_std_ch)
    freq = signal_headers[0]['sample_frequency']
    print("Original frequency ", freq)
    data = signals.T
    print("Raw data shape ", data.shape)
    mask = generate_mask_from_events(event_path, data.shape[0], freq)
    data = data[mask]
    print("Cleaned data shape ", data.shape)
    data = band_pass_filter(data, freq, ch_names = ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'T3', 'C3', 'Cz', 'C4', 'T4', 'T5', 'P3', 'Pz', 'P4', 'T6', 'O1', 'O2'])
    if freq != target_freq:
        data = resample_time_series(data, freq, target_freq)

    print("Resampled data shape ", data.shape)
    return data

# %%
# main
feature_path = 'Processed/' + sub_folder_path + '/CAUEEG/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)


# 00955.json file does not have paused event, we manually add it to the end of the file before running the code
file_root_path = 'CAUEEG/signal/edf/'
event_root_path = 'CAUEEG/event/'
for file, event in zip(os.listdir(file_root_path), os.listdir(event_root_path)):
    if file.endswith('.edf'):
        file_path = os.path.join(file_root_path, file)
        event_path = os.path.join(event_root_path, event)
        print("Processing ", file)
        data = eeg_data(file_path, event_path, li_std_ch, SAMPLE_RATE)
        print("Data shape ", data.shape)
        # save the data
        np.save(os.path.join(feature_path, file[:-4] + '.npy'), data)
        print("----------------------------------------------------------------\n")
# Out:
# Processing  00001.edf
# Original frequency  200.0
# Raw data shape  (145600, 19)
# Cleaned data shape  (133400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=133400
#     Range : 0 ... 133399 =      0.000 ...   666.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (85376, 19)
# Data shape  (85376, 19)
# ----------------------------------------------------------------
#
# Processing  00002.edf
# Original frequency  200.0
# Raw data shape  (208600, 19)
# Cleaned data shape  (191944, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=191944
#     Range : 0 ... 191943 =      0.000 ...   959.715 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (122844, 19)
# Data shape  (122844, 19)
# ----------------------------------------------------------------
#
# Processing  00003.edf
# Original frequency  200.0
# Raw data shape  (130200, 19)
# Cleaned data shape  (123600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=123600
#     Range : 0 ... 123599 =      0.000 ...   617.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (79104, 19)
# Data shape  (79104, 19)
# ----------------------------------------------------------------
#
# Processing  00004.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (152600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=152600
#     Range : 0 ... 152599 =      0.000 ...   762.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (97664, 19)
# Data shape  (97664, 19)
# ----------------------------------------------------------------
#
# Processing  00005.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (159126, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159126
#     Range : 0 ... 159125 =      0.000 ...   795.625 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (101840, 19)
# Data shape  (101840, 19)
# ----------------------------------------------------------------
#
# Processing  00006.edf
# Original frequency  200.0
# Raw data shape  (168000, 19)
# Cleaned data shape  (150200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=150200
#     Range : 0 ... 150199 =      0.000 ...   750.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (96128, 19)
# Data shape  (96128, 19)
# ----------------------------------------------------------------
#
# Processing  00007.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (164400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=164400
#     Range : 0 ... 164399 =      0.000 ...   821.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105216, 19)
# Data shape  (105216, 19)
# ----------------------------------------------------------------
#
# Processing  00008.edf
# Original frequency  200.0
# Raw data shape  (100800, 19)
# Cleaned data shape  (90030, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=90030
#     Range : 0 ... 90029 =      0.000 ...   450.145 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (57619, 19)
# Data shape  (57619, 19)
# ----------------------------------------------------------------
#
# Processing  00010.edf
# Original frequency  200.0
# Raw data shape  (201600, 19)
# Cleaned data shape  (193600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=193600
#     Range : 0 ... 193599 =      0.000 ...   967.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (123904, 19)
# Data shape  (123904, 19)
# ----------------------------------------------------------------
#
# Processing  00011.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (166800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=166800
#     Range : 0 ... 166799 =      0.000 ...   833.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (106752, 19)
# Data shape  (106752, 19)
# ----------------------------------------------------------------
#
# Processing  00012.edf
# Original frequency  200.0
# Raw data shape  (152600, 19)
# Cleaned data shape  (136400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=136400
#     Range : 0 ... 136399 =      0.000 ...   681.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (87296, 19)
# Data shape  (87296, 19)
# ----------------------------------------------------------------
#
# Processing  00013.edf
# Original frequency  200.0
# Raw data shape  (163800, 19)
# Cleaned data shape  (137214, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=137214
#     Range : 0 ... 137213 =      0.000 ...   686.065 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (87816, 19)
# Data shape  (87816, 19)
# ----------------------------------------------------------------
#
# Processing  00014.edf
# Original frequency  200.0
# Raw data shape  (128800, 19)
# Cleaned data shape  (121600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=121600
#     Range : 0 ... 121599 =      0.000 ...   607.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (77824, 19)
# Data shape  (77824, 19)
# ----------------------------------------------------------------
#
# Processing  00015.edf
# Original frequency  200.0
# Raw data shape  (176400, 19)
# Cleaned data shape  (163400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=163400
#     Range : 0 ... 163399 =      0.000 ...   816.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (104576, 19)
# Data shape  (104576, 19)
# ----------------------------------------------------------------
#
# Processing  00016.edf
# Original frequency  200.0
# Raw data shape  (124600, 19)
# Cleaned data shape  (116000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=116000
#     Range : 0 ... 115999 =      0.000 ...   579.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (74240, 19)
# Data shape  (74240, 19)
# ----------------------------------------------------------------
#
# Processing  00017.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (108600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=108600
#     Range : 0 ... 108599 =      0.000 ...   542.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (69504, 19)
# Data shape  (69504, 19)
# ----------------------------------------------------------------
#
# Processing  00018.edf
# Original frequency  200.0
# Raw data shape  (176400, 19)
# Cleaned data shape  (165400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165400
#     Range : 0 ... 165399 =      0.000 ...   826.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105856, 19)
# Data shape  (105856, 19)
# ----------------------------------------------------------------
#
# Processing  00019.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (108400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=108400
#     Range : 0 ... 108399 =      0.000 ...   541.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (69376, 19)
# Data shape  (69376, 19)
# ----------------------------------------------------------------
#
# Processing  00020.edf
# Original frequency  200.0
# Raw data shape  (152600, 19)
# Cleaned data shape  (147200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=147200
#     Range : 0 ... 147199 =      0.000 ...   735.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (94208, 19)
# Data shape  (94208, 19)
# ----------------------------------------------------------------
#
# Processing  00021.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (168400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=168400
#     Range : 0 ... 168399 =      0.000 ...   841.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (107776, 19)
# Data shape  (107776, 19)
# ----------------------------------------------------------------
#
# Processing  00022.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (112000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=112000
#     Range : 0 ... 111999 =      0.000 ...   559.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (71680, 19)
# Data shape  (71680, 19)
# ----------------------------------------------------------------
#
# Processing  00023.edf
# Original frequency  200.0
# Raw data shape  (194600, 19)
# Cleaned data shape  (182010, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=182010
#     Range : 0 ... 182009 =      0.000 ...   910.045 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (116486, 19)
# Data shape  (116486, 19)
# ----------------------------------------------------------------
#
# Processing  00024.edf
# Original frequency  200.0
# Raw data shape  (247800, 19)
# Cleaned data shape  (237800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=237800
#     Range : 0 ... 237799 =      0.000 ...  1188.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (152192, 19)
# Data shape  (152192, 19)
# ----------------------------------------------------------------
#
# Processing  00025.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (114000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=114000
#     Range : 0 ... 113999 =      0.000 ...   569.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (72960, 19)
# Data shape  (72960, 19)
# ----------------------------------------------------------------
#
# Processing  00026.edf
# Original frequency  200.0
# Raw data shape  (184800, 19)
# Cleaned data shape  (174854, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=174854
#     Range : 0 ... 174853 =      0.000 ...   874.265 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (111906, 19)
# Data shape  (111906, 19)
# ----------------------------------------------------------------
#
# Processing  00027.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (171600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=171600
#     Range : 0 ... 171599 =      0.000 ...   857.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (109824, 19)
# Data shape  (109824, 19)
# ----------------------------------------------------------------
#
# Processing  00028.edf
# Original frequency  200.0
# Raw data shape  (204400, 19)
# Cleaned data shape  (186000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=186000
#     Range : 0 ... 185999 =      0.000 ...   929.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (119040, 19)
# Data shape  (119040, 19)
# ----------------------------------------------------------------
#
# Processing  00029.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (158600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=158600
#     Range : 0 ... 158599 =      0.000 ...   792.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (101504, 19)
# Data shape  (101504, 19)
# ----------------------------------------------------------------
#
# Processing  00030.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (170400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=170400
#     Range : 0 ... 170399 =      0.000 ...   851.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (109056, 19)
# Data shape  (109056, 19)
# ----------------------------------------------------------------
#
# Processing  00031.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (164400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=164400
#     Range : 0 ... 164399 =      0.000 ...   821.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105216, 19)
# Data shape  (105216, 19)
# ----------------------------------------------------------------
#
# Processing  00032.edf
# Original frequency  200.0
# Raw data shape  (124600, 19)
# Cleaned data shape  (116800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=116800
#     Range : 0 ... 116799 =      0.000 ...   583.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (74752, 19)
# Data shape  (74752, 19)
# ----------------------------------------------------------------
#
# Processing  00033.edf
# Original frequency  200.0
# Raw data shape  (190400, 19)
# Cleaned data shape  (175942, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=175942
#     Range : 0 ... 175941 =      0.000 ...   879.705 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (112602, 19)
# Data shape  (112602, 19)
# ----------------------------------------------------------------
#
# Processing  00034.edf
# Original frequency  200.0
# Raw data shape  (135800, 19)
# Cleaned data shape  (127172, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=127172
#     Range : 0 ... 127171 =      0.000 ...   635.855 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (81390, 19)
# Data shape  (81390, 19)
# ----------------------------------------------------------------
#
# Processing  00035.edf
# Original frequency  200.0
# Raw data shape  (182000, 19)
# Cleaned data shape  (170000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=170000
#     Range : 0 ... 169999 =      0.000 ...   849.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (108800, 19)
# Data shape  (108800, 19)
# ----------------------------------------------------------------
#
# Processing  00036.edf
# Original frequency  200.0
# Raw data shape  (161000, 19)
# Cleaned data shape  (144600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=144600
#     Range : 0 ... 144599 =      0.000 ...   722.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (92544, 19)
# Data shape  (92544, 19)
# ----------------------------------------------------------------
#
# Processing  00037.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (159000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159000
#     Range : 0 ... 158999 =      0.000 ...   794.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (101760, 19)
# Data shape  (101760, 19)
# ----------------------------------------------------------------
#
# Processing  00038.edf
# Original frequency  200.0
# Raw data shape  (187600, 19)
# Cleaned data shape  (179000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=179000
#     Range : 0 ... 178999 =      0.000 ...   894.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (114560, 19)
# Data shape  (114560, 19)
# ----------------------------------------------------------------
#
# Processing  00039.edf
# Original frequency  200.0
# Raw data shape  (163800, 19)
# Cleaned data shape  (141400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=141400
#     Range : 0 ... 141399 =      0.000 ...   706.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (90496, 19)
# Data shape  (90496, 19)
# ----------------------------------------------------------------
#
# Processing  00040.edf
# Original frequency  200.0
# Raw data shape  (161000, 19)
# Cleaned data shape  (150400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=150400
#     Range : 0 ... 150399 =      0.000 ...   751.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (96256, 19)
# Data shape  (96256, 19)
# ----------------------------------------------------------------
#
# Processing  00041.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (112200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=112200
#     Range : 0 ... 112199 =      0.000 ...   560.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (71808, 19)
# Data shape  (71808, 19)
# ----------------------------------------------------------------
#
# Processing  00042.edf
# Original frequency  200.0
# Raw data shape  (182000, 19)
# Cleaned data shape  (160400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=160400
#     Range : 0 ... 160399 =      0.000 ...   801.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (102656, 19)
# Data shape  (102656, 19)
# ----------------------------------------------------------------
#
# Processing  00043.edf
# Original frequency  200.0
# Raw data shape  (198800, 19)
# Cleaned data shape  (182086, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=182086
#     Range : 0 ... 182085 =      0.000 ...   910.425 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (116535, 19)
# Data shape  (116535, 19)
# ----------------------------------------------------------------
#
# Processing  00044.edf
# Original frequency  200.0
# Raw data shape  (187600, 19)
# Cleaned data shape  (177400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=177400
#     Range : 0 ... 177399 =      0.000 ...   886.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (113536, 19)
# Data shape  (113536, 19)
# ----------------------------------------------------------------
#
# Processing  00045.edf
# Original frequency  200.0
# Raw data shape  (194600, 19)
# Cleaned data shape  (179200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=179200
#     Range : 0 ... 179199 =      0.000 ...   895.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (114688, 19)
# Data shape  (114688, 19)
# ----------------------------------------------------------------
#
# Processing  00046.edf
# Original frequency  200.0
# Raw data shape  (170800, 19)
# Cleaned data shape  (161400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=161400
#     Range : 0 ... 161399 =      0.000 ...   806.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (103296, 19)
# Data shape  (103296, 19)
# ----------------------------------------------------------------
#
# Processing  00047.edf
# Original frequency  200.0
# Raw data shape  (249200, 19)
# Cleaned data shape  (239400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=239400
#     Range : 0 ... 239399 =      0.000 ...  1196.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (153216, 19)
# Data shape  (153216, 19)
# ----------------------------------------------------------------
#
# Processing  00048.edf
# Original frequency  200.0
# Raw data shape  (170800, 19)
# Cleaned data shape  (153200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=153200
#     Range : 0 ... 153199 =      0.000 ...   765.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (98048, 19)
# Data shape  (98048, 19)
# ----------------------------------------------------------------
#
# Processing  00049.edf
# Original frequency  200.0
# Raw data shape  (144200, 19)
# Cleaned data shape  (123400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=123400
#     Range : 0 ... 123399 =      0.000 ...   616.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (78976, 19)
# Data shape  (78976, 19)
# ----------------------------------------------------------------
#
# Processing  00050.edf
# Original frequency  200.0
# Raw data shape  (197400, 19)
# Cleaned data shape  (189800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=189800
#     Range : 0 ... 189799 =      0.000 ...   948.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (121472, 19)
# Data shape  (121472, 19)
# ----------------------------------------------------------------
#
# Processing  00051.edf
# Original frequency  200.0
# Raw data shape  (131600, 19)
# Cleaned data shape  (121000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=121000
#     Range : 0 ... 120999 =      0.000 ...   604.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (77440, 19)
# Data shape  (77440, 19)
# ----------------------------------------------------------------
#
# Processing  00052.edf
# Original frequency  200.0
# Raw data shape  (159600, 19)
# Cleaned data shape  (125000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=125000
#     Range : 0 ... 124999 =      0.000 ...   624.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (80000, 19)
# Data shape  (80000, 19)
# ----------------------------------------------------------------
#
# Processing  00053.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (165600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165600
#     Range : 0 ... 165599 =      0.000 ...   827.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105984, 19)
# Data shape  (105984, 19)
# ----------------------------------------------------------------
#
# Processing  00054.edf
# Original frequency  200.0
# Raw data shape  (172200, 19)
# Cleaned data shape  (148974, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=148974
#     Range : 0 ... 148973 =      0.000 ...   744.865 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (95343, 19)
# Data shape  (95343, 19)
# ----------------------------------------------------------------
#
# Processing  00055.edf
# Original frequency  200.0
# Raw data shape  (205800, 19)
# Cleaned data shape  (194800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=194800
#     Range : 0 ... 194799 =      0.000 ...   973.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (124672, 19)
# Data shape  (124672, 19)
# ----------------------------------------------------------------
#
# Processing  00056.edf
# Original frequency  200.0
# Raw data shape  (113400, 19)
# Cleaned data shape  (88800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=88800
#     Range : 0 ... 88799 =      0.000 ...   443.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (56832, 19)
# Data shape  (56832, 19)
# ----------------------------------------------------------------
#
# Processing  00057.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (159400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159400
#     Range : 0 ... 159399 =      0.000 ...   796.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (102016, 19)
# Data shape  (102016, 19)
# ----------------------------------------------------------------
#
# Processing  00058.edf
# Original frequency  200.0
# Raw data shape  (109200, 19)
# Cleaned data shape  (96600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=96600
#     Range : 0 ... 96599 =      0.000 ...   482.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (61824, 19)
# Data shape  (61824, 19)
# ----------------------------------------------------------------
#
# Processing  00059.edf
# Original frequency  200.0
# Raw data shape  (172200, 19)
# Cleaned data shape  (160000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=160000
#     Range : 0 ... 159999 =      0.000 ...   799.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (102400, 19)
# Data shape  (102400, 19)
# ----------------------------------------------------------------
#
# Processing  00060.edf
# Original frequency  200.0
# Raw data shape  (204400, 19)
# Cleaned data shape  (197600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=197600
#     Range : 0 ... 197599 =      0.000 ...   987.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (126464, 19)
# Data shape  (126464, 19)
# ----------------------------------------------------------------
#
# Processing  00061.edf
# Original frequency  200.0
# Raw data shape  (177800, 19)
# Cleaned data shape  (164428, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=164428
#     Range : 0 ... 164427 =      0.000 ...   822.135 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105233, 19)
# Data shape  (105233, 19)
# ----------------------------------------------------------------
#
# Processing  00062.edf
# Original frequency  200.0
# Raw data shape  (130200, 19)
# Cleaned data shape  (123000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=123000
#     Range : 0 ... 122999 =      0.000 ...   614.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (78720, 19)
# Data shape  (78720, 19)
# ----------------------------------------------------------------
#
# Processing  00063.edf
# Original frequency  200.0
# Raw data shape  (140000, 19)
# Cleaned data shape  (132843, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=132843
#     Range : 0 ... 132842 =      0.000 ...   664.210 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (85019, 19)
# Data shape  (85019, 19)
# ----------------------------------------------------------------
#
# Processing  00064.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (141800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=141800
#     Range : 0 ... 141799 =      0.000 ...   708.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (90752, 19)
# Data shape  (90752, 19)
# ----------------------------------------------------------------
#
# Processing  00065.edf
# Original frequency  200.0
# Raw data shape  (166600, 19)
# Cleaned data shape  (155600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=155600
#     Range : 0 ... 155599 =      0.000 ...   777.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (99584, 19)
# Data shape  (99584, 19)
# ----------------------------------------------------------------
#
# Processing  00066.edf
# Original frequency  200.0
# Raw data shape  (168000, 19)
# Cleaned data shape  (157600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=157600
#     Range : 0 ... 157599 =      0.000 ...   787.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100864, 19)
# Data shape  (100864, 19)
# ----------------------------------------------------------------
#
# Processing  00067.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (151600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=151600
#     Range : 0 ... 151599 =      0.000 ...   757.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (97024, 19)
# Data shape  (97024, 19)
# ----------------------------------------------------------------
#
# Processing  00068.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (163000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=163000
#     Range : 0 ... 162999 =      0.000 ...   814.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (104320, 19)
# Data shape  (104320, 19)
# ----------------------------------------------------------------
#
# Processing  00069.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (165000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165000
#     Range : 0 ... 164999 =      0.000 ...   824.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105600, 19)
# Data shape  (105600, 19)
# ----------------------------------------------------------------
#
# Processing  00070.edf
# Original frequency  200.0
# Raw data shape  (172200, 19)
# Cleaned data shape  (157600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=157600
#     Range : 0 ... 157599 =      0.000 ...   787.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100864, 19)
# Data shape  (100864, 19)
# ----------------------------------------------------------------
#
# Processing  00071.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (161000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=161000
#     Range : 0 ... 160999 =      0.000 ...   804.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (103040, 19)
# Data shape  (103040, 19)
# ----------------------------------------------------------------
#
# Processing  00072.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (175400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=175400
#     Range : 0 ... 175399 =      0.000 ...   876.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (112256, 19)
# Data shape  (112256, 19)
# ----------------------------------------------------------------
#
# Processing  00073.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (115200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=115200
#     Range : 0 ... 115199 =      0.000 ...   575.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (73728, 19)
# Data shape  (73728, 19)
# ----------------------------------------------------------------
#
# Processing  00074.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (112600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=112600
#     Range : 0 ... 112599 =      0.000 ...   562.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (72064, 19)
# Data shape  (72064, 19)
# ----------------------------------------------------------------
#
# Processing  00075.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (112200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=112200
#     Range : 0 ... 112199 =      0.000 ...   560.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (71808, 19)
# Data shape  (71808, 19)
# ----------------------------------------------------------------
#
# Processing  00076.edf
# Original frequency  200.0
# Raw data shape  (165200, 19)
# Cleaned data shape  (150800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=150800
#     Range : 0 ... 150799 =      0.000 ...   753.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (96512, 19)
# Data shape  (96512, 19)
# ----------------------------------------------------------------
#
# Processing  00077.edf
# Original frequency  200.0
# Raw data shape  (191800, 19)
# Cleaned data shape  (176200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=176200
#     Range : 0 ... 176199 =      0.000 ...   880.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (112768, 19)
# Data shape  (112768, 19)
# ----------------------------------------------------------------
#
# Processing  00078.edf
# Original frequency  200.0
# Raw data shape  (186200, 19)
# Cleaned data shape  (178600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=178600
#     Range : 0 ... 178599 =      0.000 ...   892.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (114304, 19)
# Data shape  (114304, 19)
# ----------------------------------------------------------------
#
# Processing  00079.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (159800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159800
#     Range : 0 ... 159799 =      0.000 ...   798.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (102272, 19)
# Data shape  (102272, 19)
# ----------------------------------------------------------------
#
# Processing  00080.edf
# Original frequency  200.0
# Raw data shape  (138600, 19)
# Cleaned data shape  (133400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=133400
#     Range : 0 ... 133399 =      0.000 ...   666.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (85376, 19)
# Data shape  (85376, 19)
# ----------------------------------------------------------------
#
# Processing  00081.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (129400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=129400
#     Range : 0 ... 129399 =      0.000 ...   646.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (82816, 19)
# Data shape  (82816, 19)
# ----------------------------------------------------------------
#
# Processing  00082.edf
# Original frequency  200.0
# Raw data shape  (219800, 19)
# Cleaned data shape  (201616, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=201616
#     Range : 0 ... 201615 =      0.000 ...  1008.075 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (129034, 19)
# Data shape  (129034, 19)
# ----------------------------------------------------------------
#
# Processing  00083.edf
# Original frequency  200.0
# Raw data shape  (189000, 19)
# Cleaned data shape  (174800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=174800
#     Range : 0 ... 174799 =      0.000 ...   873.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (111872, 19)
# Data shape  (111872, 19)
# ----------------------------------------------------------------
#
# Processing  00084.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (109000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=109000
#     Range : 0 ... 108999 =      0.000 ...   544.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (69760, 19)
# Data shape  (69760, 19)
# ----------------------------------------------------------------
#
# Processing  00085.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (112400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=112400
#     Range : 0 ... 112399 =      0.000 ...   561.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (71936, 19)
# Data shape  (71936, 19)
# ----------------------------------------------------------------
#
# Processing  00086.edf
# Original frequency  200.0
# Raw data shape  (103600, 19)
# Cleaned data shape  (83116, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=83116
#     Range : 0 ... 83115 =      0.000 ...   415.575 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (53194, 19)
# Data shape  (53194, 19)
# ----------------------------------------------------------------
#
# Processing  00087.edf
# Original frequency  200.0
# Raw data shape  (130200, 19)
# Cleaned data shape  (115210, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=115210
#     Range : 0 ... 115209 =      0.000 ...   576.045 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (73734, 19)
# Data shape  (73734, 19)
# ----------------------------------------------------------------
#
# Processing  00088.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (156400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=156400
#     Range : 0 ... 156399 =      0.000 ...   781.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100096, 19)
# Data shape  (100096, 19)
# ----------------------------------------------------------------
#
# Processing  00089.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (155600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=155600
#     Range : 0 ... 155599 =      0.000 ...   777.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (99584, 19)
# Data shape  (99584, 19)
# ----------------------------------------------------------------
#
# Processing  00090.edf
# Original frequency  200.0
# Raw data shape  (138600, 19)
# Cleaned data shape  (102605, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=102605
#     Range : 0 ... 102604 =      0.000 ...   513.020 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (65667, 19)
# Data shape  (65667, 19)
# ----------------------------------------------------------------
#
# Processing  00091.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (157600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=157600
#     Range : 0 ... 157599 =      0.000 ...   787.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100864, 19)
# Data shape  (100864, 19)
# ----------------------------------------------------------------
#
# Processing  00092.edf
# Original frequency  200.0
# Raw data shape  (172200, 19)
# Cleaned data shape  (148000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=148000
#     Range : 0 ... 147999 =      0.000 ...   739.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (94720, 19)
# Data shape  (94720, 19)
# ----------------------------------------------------------------
#
# Processing  00093.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (116600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=116600
#     Range : 0 ... 116599 =      0.000 ...   582.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (74624, 19)
# Data shape  (74624, 19)
# ----------------------------------------------------------------
#
# Processing  00094.edf
# Original frequency  200.0
# Raw data shape  (145600, 19)
# Cleaned data shape  (124602, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=124602
#     Range : 0 ... 124601 =      0.000 ...   623.005 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (79745, 19)
# Data shape  (79745, 19)
# ----------------------------------------------------------------
#
# Processing  00095.edf
# Original frequency  200.0
# Raw data shape  (145600, 19)
# Cleaned data shape  (132322, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=132322
#     Range : 0 ... 132321 =      0.000 ...   661.605 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (84686, 19)
# Data shape  (84686, 19)
# ----------------------------------------------------------------
#
# Processing  00096.edf
# Original frequency  200.0
# Raw data shape  (184800, 19)
# Cleaned data shape  (172800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=172800
#     Range : 0 ... 172799 =      0.000 ...   863.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (110592, 19)
# Data shape  (110592, 19)
# ----------------------------------------------------------------
#
# Processing  00097.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (148200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=148200
#     Range : 0 ... 148199 =      0.000 ...   740.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (94848, 19)
# Data shape  (94848, 19)
# ----------------------------------------------------------------
#
# Processing  00098.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (162400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=162400
#     Range : 0 ... 162399 =      0.000 ...   811.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (103936, 19)
# Data shape  (103936, 19)
# ----------------------------------------------------------------
#
# Processing  00099.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (114200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=114200
#     Range : 0 ... 114199 =      0.000 ...   570.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (73088, 19)
# Data shape  (73088, 19)
# ----------------------------------------------------------------
#
# Processing  00100.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (112000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=112000
#     Range : 0 ... 111999 =      0.000 ...   559.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (71680, 19)
# Data shape  (71680, 19)
# ----------------------------------------------------------------
#
# Processing  00101.edf
# Original frequency  200.0
# Raw data shape  (119000, 19)
# Cleaned data shape  (113200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=113200
#     Range : 0 ... 113199 =      0.000 ...   565.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (72448, 19)
# Data shape  (72448, 19)
# ----------------------------------------------------------------
#
# Processing  00102.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (165200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165200
#     Range : 0 ... 165199 =      0.000 ...   825.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105728, 19)
# Data shape  (105728, 19)
# ----------------------------------------------------------------
#
# Processing  00103.edf
# Original frequency  200.0
# Raw data shape  (116200, 19)
# Cleaned data shape  (109200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=109200
#     Range : 0 ... 109199 =      0.000 ...   545.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (69888, 19)
# Data shape  (69888, 19)
# ----------------------------------------------------------------
#
# Processing  00104.edf
# Original frequency  200.0
# Raw data shape  (184800, 19)
# Cleaned data shape  (174400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=174400
#     Range : 0 ... 174399 =      0.000 ...   871.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (111616, 19)
# Data shape  (111616, 19)
# ----------------------------------------------------------------
#
# Processing  00105.edf
# Original frequency  200.0
# Raw data shape  (145600, 19)
# Cleaned data shape  (136438, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=136438
#     Range : 0 ... 136437 =      0.000 ...   682.185 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (87320, 19)
# Data shape  (87320, 19)
# ----------------------------------------------------------------
#
# Processing  00106.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (165000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165000
#     Range : 0 ... 164999 =      0.000 ...   824.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105600, 19)
# Data shape  (105600, 19)
# ----------------------------------------------------------------
#
# Processing  00107.edf
# Original frequency  200.0
# Raw data shape  (144200, 19)
# Cleaned data shape  (133600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=133600
#     Range : 0 ... 133599 =      0.000 ...   667.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (85504, 19)
# Data shape  (85504, 19)
# ----------------------------------------------------------------
#
# Processing  00108.edf
# Original frequency  200.0
# Raw data shape  (240800, 19)
# Cleaned data shape  (218599, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=218599
#     Range : 0 ... 218598 =      0.000 ...  1092.990 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (139903, 19)
# Data shape  (139903, 19)
# ----------------------------------------------------------------
#
# Processing  00109.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (115800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=115800
#     Range : 0 ... 115799 =      0.000 ...   578.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (74112, 19)
# Data shape  (74112, 19)
# ----------------------------------------------------------------
#
# Processing  00110.edf
# Original frequency  200.0
# Raw data shape  (252000, 19)
# Cleaned data shape  (246200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=246200
#     Range : 0 ... 246199 =      0.000 ...  1230.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (157568, 19)
# Data shape  (157568, 19)
# ----------------------------------------------------------------
#
# Processing  00111.edf
# Original frequency  200.0
# Raw data shape  (127400, 19)
# Cleaned data shape  (120600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=120600
#     Range : 0 ... 120599 =      0.000 ...   602.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (77184, 19)
# Data shape  (77184, 19)
# ...
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (106112, 19)
# Data shape  (106112, 19)
# ----------------------------------------------------------------
#
# Processing  00322.edf
# Original frequency  200.0
# Raw data shape  (74200, 19)
# Cleaned data shape  (71200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=71200
#     Range : 0 ... 71199 =      0.000 ...   355.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (45568, 19)
# Data shape  (45568, 19)
# ----------------------------------------------------------------
#
# Processing  00324.edf
# Original frequency  200.0
# Raw data shape  (176400, 19)
# Cleaned data shape  (156300, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=156300
#     Range : 0 ... 156299 =      0.000 ...   781.495 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100032, 19)
# Data shape  (100032, 19)
# ----------------------------------------------------------------
#
# Processing  00325.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (171200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=171200
#     Range : 0 ... 171199 =      0.000 ...   855.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (109568, 19)
# Data shape  (109568, 19)
# ----------------------------------------------------------------
#
# Processing  00326.edf
# Original frequency  200.0
# Raw data shape  (170800, 19)
# Cleaned data shape  (162600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=162600
#     Range : 0 ... 162599 =      0.000 ...   812.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (104064, 19)
# Data shape  (104064, 19)
# ----------------------------------------------------------------
#
# Processing  00327.edf
# Original frequency  200.0
# Raw data shape  (193200, 19)
# Cleaned data shape  (186000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=186000
#     Range : 0 ... 185999 =      0.000 ...   929.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (119040, 19)
# Data shape  (119040, 19)
# ----------------------------------------------------------------
#
# Processing  00328.edf
# Original frequency  200.0
# Raw data shape  (127400, 19)
# Cleaned data shape  (119400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=119400
#     Range : 0 ... 119399 =      0.000 ...   596.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (76416, 19)
# Data shape  (76416, 19)
# ----------------------------------------------------------------
#
# Processing  00329.edf
# Original frequency  200.0
# Raw data shape  (116200, 19)
# Cleaned data shape  (103000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=103000
#     Range : 0 ... 102999 =      0.000 ...   514.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (65920, 19)
# Data shape  (65920, 19)
# ----------------------------------------------------------------
#
# Processing  00330.edf
# Original frequency  200.0
# Raw data shape  (120400, 19)
# Cleaned data shape  (114800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=114800
#     Range : 0 ... 114799 =      0.000 ...   573.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (73472, 19)
# Data shape  (73472, 19)
# ----------------------------------------------------------------
#
# Processing  00331.edf
# Original frequency  200.0
# Raw data shape  (127400, 19)
# Cleaned data shape  (121800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=121800
#     Range : 0 ... 121799 =      0.000 ...   608.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (77952, 19)
# Data shape  (77952, 19)
# ----------------------------------------------------------------
#
# Processing  00332.edf
# Original frequency  200.0
# Raw data shape  (182000, 19)
# Cleaned data shape  (165400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165400
#     Range : 0 ... 165399 =      0.000 ...   826.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105856, 19)
# Data shape  (105856, 19)
# ----------------------------------------------------------------
#
# Processing  00333.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (164800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=164800
#     Range : 0 ... 164799 =      0.000 ...   823.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105472, 19)
# Data shape  (105472, 19)
# ----------------------------------------------------------------
#
# Processing  00334.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (163600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=163600
#     Range : 0 ... 163599 =      0.000 ...   817.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (104704, 19)
# Data shape  (104704, 19)
# ----------------------------------------------------------------
#
# Processing  00335.edf
# Original frequency  200.0
# Raw data shape  (134400, 19)
# Cleaned data shape  (133400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=133400
#     Range : 0 ... 133399 =      0.000 ...   666.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (85376, 19)
# Data shape  (85376, 19)
# ----------------------------------------------------------------
#
# Processing  00336.edf
# Original frequency  200.0
# Raw data shape  (182000, 19)
# Cleaned data shape  (163200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=163200
#     Range : 0 ... 163199 =      0.000 ...   815.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (104448, 19)
# Data shape  (104448, 19)
# ----------------------------------------------------------------
#
# Processing  00337.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (166800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=166800
#     Range : 0 ... 166799 =      0.000 ...   833.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (106752, 19)
# Data shape  (106752, 19)
# ----------------------------------------------------------------
#
# Processing  00338.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (158024, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=158024
#     Range : 0 ... 158023 =      0.000 ...   790.115 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (101135, 19)
# Data shape  (101135, 19)
# ----------------------------------------------------------------
#
# Processing  00339.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (159200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159200
#     Range : 0 ... 159199 =      0.000 ...   795.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (101888, 19)
# Data shape  (101888, 19)
# ----------------------------------------------------------------
#
# Processing  00340.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (170800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=170800
#     Range : 0 ... 170799 =      0.000 ...   853.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (109312, 19)
# Data shape  (109312, 19)
# ----------------------------------------------------------------
#
# Processing  00341.edf
# Original frequency  200.0
# Raw data shape  (173600, 19)
# Cleaned data shape  (159600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159600
#     Range : 0 ... 159599 =      0.000 ...   797.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (102144, 19)
# Data shape  (102144, 19)
# ----------------------------------------------------------------
#
# Processing  00342.edf
# Original frequency  200.0
# Raw data shape  (121800, 19)
# Cleaned data shape  (114600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=114600
#     Range : 0 ... 114599 =      0.000 ...   572.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (73344, 19)
# Data shape  (73344, 19)
# ----------------------------------------------------------------
#
# Processing  00343.edf
# Original frequency  200.0
# Raw data shape  (134400, 19)
# Cleaned data shape  (121232, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=121232
#     Range : 0 ... 121231 =      0.000 ...   606.155 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (77588, 19)
# Data shape  (77588, 19)
# ----------------------------------------------------------------
#
# Processing  00344.edf
# Original frequency  200.0
# Raw data shape  (175000, 19)
# Cleaned data shape  (167000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=167000
#     Range : 0 ... 166999 =      0.000 ...   834.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (106880, 19)
# Data shape  (106880, 19)
# ----------------------------------------------------------------
#
# Processing  00345.edf
# Original frequency  200.0
# Raw data shape  (131600, 19)
# Cleaned data shape  (124400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=124400
#     Range : 0 ... 124399 =      0.000 ...   621.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (79616, 19)
# Data shape  (79616, 19)
# ----------------------------------------------------------------
#
# Processing  00346.edf
# Original frequency  200.0
# Raw data shape  (168000, 19)
# Cleaned data shape  (146400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=146400
#     Range : 0 ... 146399 =      0.000 ...   731.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (93696, 19)
# Data shape  (93696, 19)
# ----------------------------------------------------------------
#
# Processing  00347.edf
# Original frequency  200.0
# Raw data shape  (176400, 19)
# Cleaned data shape  (161600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=161600
#     Range : 0 ... 161599 =      0.000 ...   807.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (103424, 19)
# Data shape  (103424, 19)
# ----------------------------------------------------------------
#
# Processing  00348.edf
# Original frequency  200.0
# Raw data shape  (180600, 19)
# Cleaned data shape  (166400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=166400
#     Range : 0 ... 166399 =      0.000 ...   831.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (106496, 19)
# Data shape  (106496, 19)
# ----------------------------------------------------------------
#
# Processing  00349.edf
# Original frequency  200.0
# Raw data shape  (179200, 19)
# Cleaned data shape  (165800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165800
#     Range : 0 ... 165799 =      0.000 ...   828.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (106112, 19)
# Data shape  (106112, 19)
# ----------------------------------------------------------------
#
# Processing  00350.edf
# Original frequency  200.0
# Raw data shape  (170800, 19)
# Cleaned data shape  (145196, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=145196
#     Range : 0 ... 145195 =      0.000 ...   725.975 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (92925, 19)
# Data shape  (92925, 19)
# ----------------------------------------------------------------
#
# Processing  00351.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (159200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=159200
#     Range : 0 ... 159199 =      0.000 ...   795.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (101888, 19)
# Data shape  (101888, 19)
# ----------------------------------------------------------------
#
# Processing  00352.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (156600, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=156600
#     Range : 0 ... 156599 =      0.000 ...   782.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100224, 19)
# Data shape  (100224, 19)
# ----------------------------------------------------------------
#
# Processing  00353.edf
# Original frequency  200.0
# Raw data shape  (187600, 19)
# Cleaned data shape  (175000, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=175000
#     Range : 0 ... 174999 =      0.000 ...   874.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (112000, 19)
# Data shape  (112000, 19)
# ----------------------------------------------------------------
#
# Processing  00354.edf
# Original frequency  200.0
# Raw data shape  (123200, 19)
# Cleaned data shape  (117400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=117400
#     Range : 0 ... 117399 =      0.000 ...   586.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (75136, 19)
# Data shape  (75136, 19)
# ----------------------------------------------------------------
#
# Processing  00355.edf
# Original frequency  200.0
# Raw data shape  (183400, 19)
# Cleaned data shape  (165400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=165400
#     Range : 0 ... 165399 =      0.000 ...   826.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (105856, 19)
# Data shape  (105856, 19)
# ----------------------------------------------------------------
#
# Processing  00356.edf
# Original frequency  200.0
# Raw data shape  (169400, 19)
# Cleaned data shape  (150200, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=150200
#     Range : 0 ... 150199 =      0.000 ...   750.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (96128, 19)
# Data shape  (96128, 19)
# ----------------------------------------------------------------
#
# Processing  00357.edf
# Original frequency  200.0
# Raw data shape  (182000, 19)
# Cleaned data shape  (168400, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=168400
#     Range : 0 ... 168399 =      0.000 ...   841.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (107776, 19)
# Data shape  (107776, 19)
# ----------------------------------------------------------------
#
# Processing  00358.edf
# Original frequency  200.0
# Raw data shape  (170800, 19)
# Cleaned data shape  (156800, 19)
# Creating RawArray with float64 data, n_channels=19, n_times=156800
#     Range : 0 ... 156799 =      0.000 ...   783.995 secs
# Ready.
# ✔ Montage set: 'standard_1020'.
# ✔ Bandpass filter applied (0.5–45 Hz).
# Resampled data shape  (100352, 19)
# Data shape  (100352, 19)
# ----------------------------------------------------------------
#
# Processing  00359.edf

# %%
# Test the saved npy file
# example

path = feature_path

total_length = 0
for file in os.listdir(path):
    sub_path = os.path.join(path, file)
    print(np.load(sub_path).shape)
    total_length += np.load(sub_path).shape[0]
print("\nTotal length:", total_length)
# Out:
# (85376, 19)
# (122844, 19)
# (79104, 19)
# (97664, 19)
# (101840, 19)
# (96128, 19)
# (105216, 19)
# (57619, 19)
# (123904, 19)
# (106752, 19)
# (87296, 19)
# (87816, 19)
# (77824, 19)
# (104576, 19)
# (74240, 19)
# (69504, 19)
# (105856, 19)
# (69376, 19)
# (94208, 19)
# (107776, 19)
# (71680, 19)
# (116486, 19)
# (152192, 19)
# (72960, 19)
# (111906, 19)
# (109824, 19)
# (119040, 19)
# (101504, 19)
# (109056, 19)
# (105216, 19)
# (74752, 19)
# (112602, 19)
# (81390, 19)
# (108800, 19)
# (92544, 19)
# (101760, 19)
# (114560, 19)
# (90496, 19)
# (96256, 19)
# (71808, 19)
# (102656, 19)
# (116535, 19)
# (113536, 19)
# (114688, 19)
# (103296, 19)
# (153216, 19)
# (98048, 19)
# (78976, 19)
# (121472, 19)
# (77440, 19)
# (80000, 19)
# (105984, 19)
# (95343, 19)
# (124672, 19)
# (56832, 19)
# (102016, 19)
# (61824, 19)
# (102400, 19)
# (126464, 19)
# (105233, 19)
# (78720, 19)
# (85019, 19)
# (90752, 19)
# (99584, 19)
# (100864, 19)
# (97024, 19)
# (104320, 19)
# (105600, 19)
# (100864, 19)
# (103040, 19)
# (112256, 19)
# (73728, 19)
# (72064, 19)
# (71808, 19)
# (96512, 19)
# (112768, 19)
# (114304, 19)
# (102272, 19)
# (85376, 19)
# (82816, 19)
# (129034, 19)
# (111872, 19)
# (69760, 19)
# (71936, 19)
# (53194, 19)
# (73734, 19)
# (100096, 19)
# (99584, 19)
# (65667, 19)
# (100864, 19)
# (94720, 19)
# (74624, 19)
# (79745, 19)
# (84686, 19)
# (110592, 19)
# (94848, 19)
# (103936, 19)
# (73088, 19)
# (71680, 19)
# (72448, 19)
# (105728, 19)
# (69888, 19)
# (111616, 19)
# (87320, 19)
# (105600, 19)
# (85504, 19)
# (139903, 19)
# (74112, 19)
# (157568, 19)
# (77184, 19)
# (72317, 19)
# (75008, 19)
# (100224, 19)
# (104019, 19)
# (98944, 19)
# (111744, 19)
# (98176, 19)
# (103936, 19)
# (112256, 19)
# (81024, 19)
# (72832, 19)
# (105856, 19)
# (71680, 19)
# (72704, 19)
# (116225, 19)
# (78407, 19)
# (95616, 19)
# (106112, 19)
# (104064, 19)
# (112802, 19)
# (98432, 19)
# (94848, 19)
# (104832, 19)
# (105344, 19)
# (112768, 19)
# (82944, 19)
# (72062, 19)
# (100992, 19)
# (62208, 19)
# (99872, 19)
# (62976, 19)
# (97792, 19)
# (98304, 19)
# (105984, 19)
# (54144, 19)
# (97920, 19)
# (157312, 19)
# (71936, 19)
# (71680, 19)
# (79744, 19)
# (106112, 19)
# (71936, 19)
# (104320, 19)
# (88192, 19)
# (77245, 19)
# (77568, 19)
# (75392, 19)
# (53672, 19)
# (72192, 19)
# (71680, 19)
# (72192, 19)
# (71680, 19)
# (78208, 19)
# (75136, 19)
# (72192, 19)
# (75776, 19)
# (118144, 19)
# (110336, 19)
# (50688, 19)
